# %% [markdown]
# <img src = "images/3_logos.png" width = 600, align = "center">
# <br>
# <h1 align=center><font size = 5>Chipoltle</font></h1>
# <h2 align=center><font size = 5>Filtrer et Trier</font></h2>

# %% [markdown]
# ### 1. Importer les librairies nécessaires

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### 2. Importer le jeu de données depuis [adresse](https://needemand.com/keepsmiling2/index.php/s/9KGweKQ3SDgJNYQ).

# %% [markdown]
# ### 3. Affecter les données à une variable chipo.

# %%
chipo=  pd.read_table("data/chipotle.tsv", encoding='utf-8' )
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ###  4. Combien de produits coûtent plus de $10.00?

# %%
P=chipo["price"] = pd.to_numeric(chipo["item_price"].apply(lambda x: str(x)[1:]))
P

B=chipo[chipo["price"] > 10.00]
B.count()
# Out:
# order_id              1130
# quantity              1130
# item_name             1130
# choice_description    1123
# item_price            1130
# price                 1130
# dtype: int64

# %% [markdown]
# ###  5. Quel est le prix de chaque produit ?
# ###### Afficher un dataframe de 2 colonnes item_name et item_price

# %%
#chipo.iloc[0:,2:5:2 ] 
chipo[['item_name','price']]
# Out:
#                                   item_name  price
# 0              Chips and Fresh Tomato Salsa   2.39
# 1                                      Izze   3.39
# 2                          Nantucket Nectar   3.39
# 3     Chips and Tomatillo-Green Chili Salsa   2.39
# 4                              Chicken Bowl  16.98
# 5                              Chicken Bowl  10.98
# 6                             Side of Chips   1.69
# 7                             Steak Burrito  11.75
# 8                          Steak Soft Tacos   9.25
# 9                             Steak Burrito   9.25
# 10                      Chips and Guacamole   4.45
# 11                     Chicken Crispy Tacos   8.75
# 12                       Chicken Soft Tacos   8.75
# 13                             Chicken Bowl  11.25
# 14                      Chips and Guacamole   4.45
# 15    Chips and Tomatillo-Green Chili Salsa   2.39
# 16                          Chicken Burrito   8.49
# ...

# %% [markdown]
# ### 6. Trier nom d'article

# %%
chipo['item_name'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
# 5                                Chicken Bowl
# 6                               Side of Chips
# 7                               Steak Burrito
# 8                            Steak Soft Tacos
# 9                               Steak Burrito
# 10                        Chips and Guacamole
# 11                       Chicken Crispy Tacos
# 12                         Chicken Soft Tacos
# 13                               Chicken Bowl
# 14                        Chips and Guacamole
# 15      Chips and Tomatillo-Green Chili Salsa
# 16                            Chicken Burrito
# 17                            Chicken Burrito
# 18                                Canned Soda
# 19                               Chicken Bowl
# ...

# %% [markdown]
# ### 7. Quelle était la quantité commandée de l'article le plus cher ?

# %%
#Z=chipo['price'].max()
#Z
chipo['result']=chipo['price']/chipo['quantity']
chipo['result'].max()
# Out:
# 11.89

# %%
chipo[chipo['quantity'].notnull() & (chipo['price']== chipo['result'].max() )].sum()
# Out:
# order_id                                                          24623
# quantity                                                             26
# item_name             Steak Salad BowlSteak Salad BowlCarnitas Salad...
# choice_description    [Fresh Tomato Salsa, [Pinto Beans, Cheese, Gua...
# item_price            $11.89 $11.89 $11.89 $11.89 $11.89 $11.89 $11....
# price                                                            309.14
# result                                                           309.14
# dtype: object

# %% [markdown]
# ### 8. Combien de fois l'article Veggie Salad Bowl a t-il été commandé?

# %%
chipo[chipo.item_name == 'Veggie Salad Bowl'].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# price                 18
# result                18
# dtype: int64

# %% [markdown]
# ### 9. Combien de commandes comportent plus d'une Canned Soda?

# %%
(chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)]).count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# price                 20
# result                20
# dtype: int64

# %% [markdown]
# <hr>
# Copyright &copy; 2018 Hatem & Driss @NEEDEMAND
